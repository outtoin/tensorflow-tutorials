# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.0.1'

# %%
print(1)
# Out:
# 1

# %%
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')
hypothesis = X * W + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(20001):
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train],
                feed_dict={X: [1, 2, 3, 4, 5], Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# (0, 2.4364977e-07, array([ 1.00031948], dtype=float32), array([ 1.09884691], dtype=float32))
# (20, 2.1281883e-07, array([ 1.00029838], dtype=float32), array([ 1.09892237], dtype=float32))
# (40, 1.8585261e-07, array([ 1.00027907], dtype=float32), array([ 1.09899294], dtype=float32))
# (60, 1.6238718e-07, array([ 1.00026071], dtype=float32), array([ 1.09905875], dtype=float32))
# (80, 1.4180887e-07, array([ 1.00024378], dtype=float32), array([ 1.09912014], dtype=float32))
# (100, 1.2385749e-07, array([ 1.00022769], dtype=float32), array([ 1.09917784], dtype=float32))
# (120, 1.0823065e-07, array([ 1.00021303], dtype=float32), array([ 1.09923148], dtype=float32))
# (140, 9.448646e-08, array([ 1.00019884], dtype=float32), array([ 1.09928191], dtype=float32))
# (160, 8.2551651e-08, array([ 1.00018597], dtype=float32), array([ 1.09932876], dtype=float32))
# (180, 7.2179787e-08, array([ 1.00017381], dtype=float32), array([ 1.09937251], dtype=float32))
# (200, 6.2984597e-08, array([ 1.00016236], dtype=float32), array([ 1.09941363], dtype=float32))
# (220, 5.4995827e-08, array([ 1.00015175], dtype=float32), array([ 1.09945214], dtype=float32))
# (240, 4.8068443e-08, array([ 1.00014198], dtype=float32), array([ 1.0994879], dtype=float32))
# (260, 4.2013482e-08, array([ 1.00013244], dtype=float32), array([ 1.09952128], dtype=float32))
# (280, 3.669512e-08, array([ 1.00012386], dtype=float32), array([ 1.09955263], dtype=float32))
# (300, 3.2054231e-08, array([ 1.00011587], dtype=float32), array([ 1.09958184], dtype=float32))
# (320, 2.798895e-08, array([ 1.00010836], dtype=float32), array([ 1.09960902], dtype=float32))
# (340, 2.4474048e-08, array([ 1.00010121], dtype=float32), array([ 1.09963453], dtype=float32))
# (360, 2.139268e-08, array([ 1.00009453], dtype=float32), array([ 1.09965837], dtype=float32))
# (380, 1.8687388e-08, array([ 1.00008845], dtype=float32), array([ 1.09968054], dtype=float32))
# (400, 1.6302067e-08, array([ 1.00008261], dtype=float32), array([ 1.09970176], dtype=float32))
# (420, 1.4291357e-08, array([ 1.00007737], dtype=float32), array([ 1.09972084], dtype=float32))
# (440, 1.2448993e-08, array([ 1.00007236], dtype=float32), array([ 1.09973907], dtype=float32))
# (460, 1.0907399e-08, array([ 1.00006759], dtype=float32), array([ 1.09975576], dtype=float32))
# (480, 9.4661576e-09, array([ 1.00006294], dtype=float32), array([ 1.09977245], dtype=float32))
# (500, 8.3055056e-09, array([ 1.00005889], dtype=float32), array([ 1.09978688], dtype=float32))
# (520, 7.2515034e-09, array([ 1.00005496], dtype=float32), array([ 1.09980118], dtype=float32))
# (540, 6.3378591e-09, array([ 1.0000515], dtype=float32), array([ 1.09981394], dtype=float32))
# (560, 5.5661986e-09, array([ 1.00004828], dtype=float32), array([ 1.09982586], dtype=float32))
# (580, 4.8316111e-09, array([ 1.00004494], dtype=float32), array([ 1.09983778], dtype=float32))
# (600, 4.2407464e-09, array([ 1.0000422], dtype=float32), array([ 1.09984767], dtype=float32))
# (620, 3.7452081e-09, array([ 1.0000397], dtype=float32), array([ 1.09985721], dtype=float32))
# (640, 3.2478056e-09, array([ 1.00003707], dtype=float32), array([ 1.09986675], dtype=float32))
# (660, 2.8357134e-09, array([ 1.00003457], dtype=float32), array([ 1.09987545], dtype=float32))
# (680, 2.5164808e-09, array([ 1.00003231], dtype=float32), array([ 1.0998826], dtype=float32))
# (700, 2.226443e-09, array([ 1.0000304], dtype=float32), array([ 1.09988976], dtype=float32))
# (720, 1.9422259e-09, array([ 1.00002837], dtype=float32), array([ 1.09989691], dtype=float32))
# (740, 1.6824743e-09, array([ 1.00002646], dtype=float32), array([ 1.09990406], dtype=float32))
# (760, 1.4425495e-09, array([ 1.00002456], dtype=float32), array([ 1.09991121], dtype=float32))
# (780, 1.2581154e-09, array([ 1.00002301], dtype=float32), array([ 1.09991682], dtype=float32))
# (800, 1.1222709e-09, array([ 1.00002158], dtype=float32), array([ 1.09992158], dtype=float32))
# (820, 9.900305e-10, array([ 1.00002038], dtype=float32), array([ 1.09992635], dtype=float32))
# (840, 8.6970431e-10, array([ 1.00001907], dtype=float32), array([ 1.09993112], dtype=float32))
# (860, 7.472522e-10, array([ 1.00001776], dtype=float32), array([ 1.09993589], dtype=float32))
# (880, 6.391474e-10, array([ 1.00001645], dtype=float32), array([ 1.09994066], dtype=float32))
# (900, 5.4433258e-10, array([ 1.00001514], dtype=float32), array([ 1.09994543], dtype=float32))
# (920, 4.8294169e-10, array([ 1.00001431], dtype=float32), array([ 1.09994853], dtype=float32))
# (940, 4.3643239e-10, array([ 1.00001359], dtype=float32), array([ 1.09995091], dtype=float32))
# (960, 3.9809719e-10, array([ 1.00001299], dtype=float32), array([ 1.09995329], dtype=float32))
# (980, 3.5757922e-10, array([ 1.00001228], dtype=float32), array([ 1.09995568], dtype=float32))
# (1000, 3.1988065e-10, array([ 1.00001168], dtype=float32), array([ 1.09995806], dtype=float32))
# (1020, 2.8512659e-10, array([ 1.00001097], dtype=float32), array([ 1.09996045], dtype=float32))
# (1040, 2.5180497e-10, array([ 1.00001037], dtype=float32), array([ 1.09996283], dtype=float32))
# (1060, 2.1933602e-10, array([ 1.00000966], dtype=float32), array([ 1.09996521], dtype=float32))
# (1080, 1.9167601e-10, array([ 1.00000906], dtype=float32), array([ 1.0999676], dtype=float32))
# (1100, 1.6467538e-10, array([ 1.00000834], dtype=float32), array([ 1.09996998], dtype=float32))
# (1120, 1.3975524e-10, array([ 1.00000775], dtype=float32), array([ 1.09997237], dtype=float32))
# (1140, 1.1687007e-10, array([ 1.00000715], dtype=float32), array([ 1.09997475], dtype=float32))
# (1160, 9.6235908e-11, array([ 1.00000644], dtype=float32), array([ 1.09997714], dtype=float32))
# (1180, 7.6624929e-11, array([ 1.00000584], dtype=float32), array([ 1.09997928], dtype=float32))
# (1200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (1980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (2980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (3980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (4980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (5980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (6980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (7980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (8980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (9980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# ...
# (16740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (16980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (17980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (18980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19020, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19040, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19060, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19080, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19100, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19120, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19140, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19160, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19180, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19200, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19220, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19240, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19260, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19280, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19300, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19320, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19340, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19360, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19380, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19400, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19420, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19440, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19460, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19480, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19500, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19520, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19540, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19560, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19580, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19600, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19620, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19640, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19660, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19680, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19700, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19720, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19740, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19760, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19780, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19800, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19820, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19840, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19860, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19880, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19900, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19920, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19940, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19960, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (19980, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))
# (20000, 7.5044679e-11, array([ 1.00000584], dtype=float32), array([ 1.09997952], dtype=float32))

# %%
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [ 6.10000849]
# [ 3.59999418]
# [ 2.59998846  4.5999999 ]
